# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\user\\OneDrive\\Desktop\\scatter-plotter'

# %%
cd C:\\Users\\user\\OneDrive\\Desktop\\CSV files
# Out:
# C:\Users\user\OneDrive\Desktop\CSV files

# %%
data = pd.read_csv('top50.csv',encoding='ISO-8859-1')
data
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute',
#        'Energy', 'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.',
#        'Length.', 'Acousticness..', 'Speechiness.', 'Popularity'],
#       dtype='object')

# %%
data['Genre'].value_counts().head()
# Out:
# dance pop           8
# pop                 7
# latin               5
# edm                 3
# canadian hip hop    3
# Name: Genre, dtype: int64

# %%
data['Artist.Name'].value_counts().head(10)
# Out:
# Ed Sheeran          4
# Billie Eilish       2
# Lil Nas X           2
# The Chainsmokers    2
# Ariana Grande       2
# Marshmello          2
# Post Malone         2
# Shawn Mendes        2
# J Balvin            2
# Sech                2
# Name: Artist.Name, dtype: int64

# %%
data_group_by_genre = data.groupby('Genre').mean()

# %%
def plot_genre_analysis(feat):    
    plt.figure(figsize=(8,6))
    sns.barplot(data=data,y=data_group_by_genre.sort_values(by=feat,ascending=False).index,x=data_group_by_genre.sort_values(by=feat,ascending=False)[feat])

# %%
import seaborn as sns
for col in data.select_dtypes(exclude='O').columns:
    plot_genre_analysis(col)

# %%
for item in data.select_dtypes(exclude='O'):
    fig,ax = plt.subplots(nrows=1,ncols=1)
    sns.distplot(data[item],ax=ax)
    plt.grid()

# %%
column_to_pair = data.select_dtypes(exclude='O')
for item in column_to_pair:
    fig,ax = plt.subplots(nrows=1,ncols=1)
    sns.scatterplot(data['Popularity'],data[item],ax=ax)
    plt.grid()

# %%
column_to_pair = data.select_dtypes(exclude='O').drop('Unnamed: 0',axis=1).columns
for item in column_to_pair:
    fig,ax = plt.subplots(nrows=1,ncols=1)
    sns.scatterplot(data['Unnamed: 0'],data[item],ax=ax)
    plt.grid()
