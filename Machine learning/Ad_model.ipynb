# %%
pwd
# Out:
# 'C:\\Users\\user\\OneDrive\\Desktop\\scatter-plotter\\Machine learning'

# %%
cd C:\\Users\\user\\OneDrive\\Desktop\\CSV files
# Out:
# C:\Users\user\OneDrive\Desktop\CSV files

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
data = pd.read_csv('Advertising.csv',index_col=0)
data.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
data.shape
# Out:
# (200, 4)

# %%
sns.pairplot(data,x_vars = ['TV','radio','newspaper'],y_vars = 'sales',height = 7,aspect = 0.7,kind = 'reg',markers = 'H')

# %%
real_x = data.iloc[:,2].values
real_y = data.iloc[:,3].values
real_x = real_x.reshape(-1,1)
real_y = real_y.reshape(-1,1)

# %%
real_x.shape
# Out:
# (200, 1)

# %%
print(type(x))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
training_x,testing_x,training_y,testing_y = train_test_split(real_x,real_y,test_size=0.3,random_state = 0)
testing_x
# Out:
# array([[ 18.3],
#        [ 18.4],
#        [ 23.2],
#        [ 51.2],
#        [ 35.2],
#        [ 29.7],
#        [ 75. ],
#        [  8.7],
#        [ 65.9],
#        [ 14.2],
#        [ 54.7],
#        [ 25.9],
#        [  8.3],
#        [  9.5],
#        [ 22.3],
#        [ 11.6],
#        [  0.3],
#        [  8.7],
#        [ 45.7],
#        [ 13.1],
#        [ 71.8],
#        [  9. ],
#        [ 31.5],
#        [ 34.6],
#        [ 21.4],
#        [ 12.4],
#        [ 17.6],
#        [ 19.6],
#        [ 15.6],
#        [ 43.3],
#        [114. ],
#        [ 60. ],
#        [ 37. ],
#        [ 23.2],
#        [ 49.6],
#        [ 23.4],
#        [ 43.1],
#        [ 58.4],
#        [ 35.6],
#        [ 29.7],
#        [ 65.6],
#        [  2.2],
#        [ 12.6],
#        [ 10.7],
#        [ 57.6],
#        [  8.4],
#        [  1. ],
#        [ 89.4],
#        [ 79.2],
#        [ 34.4],
#        [ 31.7],
#        [ 74.2],
#        [ 30. ],
#        [ 22. ],
#        [ 20.6],
# ...

# %%
lin = LinearRegression()
lin.fit(training_x,training_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pred_y = lin.predict(testing_x)

# %%
testing_y[4]
# Out:
# array([11.7])

# %%
pred_y[4]
# Out:
# array([14.74833473])

# %%
plt.scatter(training_x,training_y,color = 'green')
plt.plot(training_x,lin.predict(training_x),color = 'red')
plt.title('newspaper and sales')

plt.show()

# %%
plt.scatter(testing_x,testing_y,color = 'green')
plt.plot(training_x,lin.predict(training_x),color = 'red')
plt.title('newspaper and sales')

plt.show()

# %%
# y = bx + c
lin.coef_
# Out:
# array([[0.06763487]])

# %%
lin.intercept_
# Out:
# array([12.36758718])

# %%
0.06763487*45.1+12.36758718
# Out:
# 15.417919817

# %%
0.06763487*58.5+12.36758718
# Out:
# 16.324227075
