# %%
pwd
# Out:
# 'C:\\Users\\user\\OneDrive\\Desktop\\scatter-plotter'

# %%
cd C:\\Users\\user\\OneDrive\\Desktop\\CSV files
# Out:
# C:\Users\user\OneDrive\Desktop\CSV files

# %%
pwd
# Out:
# 'C:\\Users\\user\\OneDrive\\Desktop\\CSV files'

# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_csv('data.csv')

# %%
data
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
data.head(15)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
# 14          14  215914           N. Kanté   27
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# ...

# %%
data.count()
# Out:
# Unnamed: 0                  18207
# ID                          18207
# Name                        18207
# Age                         18207
# Photo                       18207
# Nationality                 18207
# Flag                        18207
# Overall                     18207
# Potential                   18207
# Club                        17966
# Club Logo                   18207
# Value                       18207
# Wage                        18207
# Special                     18207
# Preferred Foot              18159
# International Reputation    18159
# Weak Foot                   18159
# Skill Moves                 18159
# Work Rate                   18159
# Body Type                   18159
# Real Face                   18159
# Position                    18147
# Jersey Number               18147
# Joined                      16654
# Loaned From                  1264
# Contract Valid Until        17918
# Height                      18159
# ...

# %%
data['Age'].min()
# Out:
# 16

# %%
data['Age'].max()
# Out:
# 45

# %%
plt.scatter(data['ID'], data ['Potential'],color = "grey", alpha=.7)
plt.title(" ID vs Potential",color = 'green')

plt.xlabel("ID", color = 'black')
plt.ylabel("Potential", color = 'black')
plt.show()
