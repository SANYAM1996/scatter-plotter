# %%
pwd
# Out:
# 'C:\\Users\\user\\OneDrive\\Desktop\\scatter-plotter'

# %%
cd C:\\Users\\user\\OneDrive\\Desktop\\CSV files
# Out:
# C:\Users\user\OneDrive\Desktop\CSV files

# %%
pwd
# Out:
# 'C:\\Users\\user\\OneDrive\\Desktop\\CSV files'

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
data = pd.read_csv('data.csv')

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# ...

# %%
# lets see some statistics
data.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
# lets see the shape of data
data.shape
# Out:
# (18207, 89)

# %%
# lets findout unique number in dataset
data.nunique()
# Out:
# Unnamed: 0                  18207
# ID                          18207
# Name                        17194
# Age                            29
# Photo                       18207
# Nationality                   164
# Flag                          164
# Overall                        48
# Potential                      47
# Club                          651
# Club Logo                     679
# Value                         217
# Wage                          144
# Special                      1422
# Preferred Foot                  2
# International Reputation        5
# Weak Foot                       5
# Skill Moves                     5
# Work Rate                       9
# Body Type                      10
# Real Face                       2
# Position                       27
# Jersey Number                  99
# Joined                       1736
# Loaned From                   341
# Contract Valid Until           36
# Height                         21
# ...

# %%
# lets check some Nan values
data.isnull().any()
# Out:
# Unnamed: 0                  False
# ID                          False
# Name                        False
# Age                         False
# Photo                       False
# Nationality                 False
# Flag                        False
# Overall                     False
# Potential                   False
# Club                         True
# Club Logo                   False
# Value                       False
# Wage                        False
# Special                     False
# Preferred Foot               True
# International Reputation     True
# Weak Foot                    True
# Skill Moves                  True
# Work Rate                    True
# Body Type                    True
# Real Face                    True
# Position                     True
# Jersey Number                True
# Joined                       True
# Loaned From                  True
# Contract Valid Until         True
# Height                       True
# ...

# %%
# whats columns are in data set
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
# lets choose columns in which we are intrested
chosen_columns = [
    'Name',
    'Age',
    'Nationality',
    'Overall',
    'Potential',
    'Special',
    'Acceleration',
    'Aggression',
    'Agility',
    'Balance',
    'BallControl',
    'Body Type',
    'Composure',
    'Crossing',
    'Curve',
    'Club',
    'Dribbling',
    'FKAccuracy',
    'Finishing',
    'GKDiving',
    'GKHandling',
    'GKKicking',
    'GKPositioning',
    'GKReflexes',
    'HeadingAccuracy',
    'Interceptions',
    'International Reputation',
    'Jersey Number',
    'Jumping',
    'Joined',
    'LongPassing',
    'LongShots',
    'Marking',
    'Penalties',
    'Position',
    'Positioning',
    'Preferred Foot',
    'Reactions',
    'ShortPassing',
    'ShotPower',
    'Skill Moves',
    'SlidingTackle',
    'SprintSpeed',
    'Stamina',
    'StandingTackle',
    'Strength',
    'Value',
    'Vision',
    'Volleys',
    'Wage',
    'Weak Foot',
    'Work Rate'
]

# %%
# i created new dataframe with above columns
df=pd.DataFrame(data,columns=chosen_columns)

# %%
df.sample(10)
# Out:
#                  Name  Age Nationality  Overall  Potential  Special  \
# 2770         H. Afful   32       Ghana       73         73     1977
# 10061    M. Coppolaro   21       Italy       65         79     1615
# 5283        T. Kister   31     Germany       70         70     1401
# 10415       T. Ndenge   21     Germany       65         74     1774
# 10709       M. Fetsch   29     Germany       65         65     1571
# 11626       F. Jensen   25      Norway       64         68     1701
# 7078      R. Majewski   31      Poland       68         68     1839
# 1545         E. Insúa   29   Argentina       76         76     2056
# 17204        C. López   23    Colombia       55         65      988
# 4283   O. Vizcarrondo   34   Venezuela       71         71     1397
#
#        Acceleration  Aggression  Agility  Balance  BallControl Body Type  \
# 2770           79.0        69.0     77.0     79.0         71.0      Lean
# ...

# %%
import seaborn as sns

# %%
# lets create correlation heat map
plt.rcParams['figure.figsize']=(30,20)
hm=sns.heatmap(df[['Age', 'Overall', 'Potential', 'Value', 'Wage',
                'Acceleration', 'Aggression', 'Agility', 'Balance', 'BallControl', 
                'Body Type','Composure', 'Crossing','Dribbling', 'FKAccuracy', 'Finishing', 
                'HeadingAccuracy', 'Interceptions','International Reputation',
                'Joined', 'Jumping', 'LongPassing', 'LongShots',
                'Marking', 'Penalties', 'Position', 'Positioning',
                'ShortPassing', 'ShotPower', 'Skill Moves', 'SlidingTackle',
                'SprintSpeed', 'Stamina', 'StandingTackle', 'Strength', 'Vision',
                'Volleys']].corr(), annot = True, linewidths=.5, cmap='gray')
hm.set_title(label='Heatmap of dataset', fontsize=20)
hm;

# %%
# Histogram: number of players's age
sns.set(style ="dark", palette="colorblind", color_codes=True)
x = df.Age
plt.figure(figsize=(12,8))
ax = sns.distplot(x, bins = 58, kde = False, color='r')
ax.set_xlabel(xlabel="Player\'s age", fontsize=16)
ax.set_ylabel(ylabel='Number of players', fontsize=16)
ax.set_title(label='Histogram of players age', fontsize=20)
plt.grid(True)
plt.show()

# %%
# making scatter plotter between accleration and other chosen field
def A (df):
    feats = ('Agility','Balance','Dribbling','SprintSpeed')
    
    for index, feat in enumerate(feats):
        plt.subplot(len(feats)/4+1,4,index+1)
        ax = sns.regplot(x= 'Acceleration',y = feat,data = df)
plt.figure(figsize=(20,20))
plt.subplots_adjust(hspace = 0.4)
A(df)

# %%
# lets find out the elder players in dataset
elder = df.sort_values('Age',ascending = False)[['Name','Nationality','Age']].head(20)
elder.set_index('Name',inplace=True)
print(elder)
# Out:
#                        Nationality  Age
# Name
# O. Pérez                    Mexico   45
# K. Pilkington              England   44
# T. Warner        Trinidad & Tobago   44
# S. Narazaki                  Japan   42
# C. Muñoz                 Argentina   41
# J. Villar                 Paraguay   41
# H. Sulaimani          Saudi Arabia   41
# M. Tyler                   England   41
# B. Nivet                    France   41
# F. Kippe                    Norway   40
# P. van der Vlag        Netherlands   40
# B. Castillo               Colombia   40
# C. Lucchetti             Argentina   40
# S. Bertoli               Argentina   40
# S. Nakamura                  Japan   40
# A. Bizzarri              Argentina   40
# Y. Nakazawa                  Japan   40
# G. Buffon                    Italy   40
# Hilton                      Brazil   40
# W. Díaz                   Colombia   40

# %%
# lets find out the youngest players in dataset
youngest = df.sort_values('Age',ascending = True)[['Name','Nationality','Age']].head(20)
youngest.set_index('Name',inplace=True)
print(youngest)
# Out:
#                         Nationality  Age
# Name
# G. Nugent                   England   16
# J. Olstad                    Norway   16
# H. Massengo                  France   16
# J. Italiano               Australia   16
# N. Ayéva                     Sweden   16
# K. Broda                     Poland   16
# L. D'Arrigo               Australia   16
# Y. Verschaeren              Belgium   16
# B. Nygren                    Sweden   16
# B. O'Gorman     Republic of Ireland   16
# A. Doğan                     Turkey   16
# C. Bassett            United States   16
# J. Lahne                     Sweden   16
# Y. Begraoui                  France   16
# B. Mumba                    England   16
# J. Imbrechts                 Sweden   16
# J. Cleary       Republic of Ireland   16
# R. Gómez                  Argentina   16
# H. Andersson                 Sweden   16
# M. Larsen                   Denmark   16

# %%
# Compare six clubs in relation to age
some_clubs = ('Juventus', 'Real Madrid', 'Manchester City', 'FC Barcelona', 'Paris FC', 'Manchester United')
df_club = df.loc[df['Club'].isin(some_clubs) & df['Age']]

fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax = sns.violinplot(x="Club", y="Age", data=df_club);
ax.set_title(label='Distribution of age in some clubs', fontsize=20);

# %%
# lets see the oldest team
df.groupby(['Club'])['Age'].sum().sort_values(ascending = False).head(20)
# Out:
# Club
# Cardiff City                  863
# Villarreal CF                 851
# Burnley                       850
# Frosinone                     843
# Chelsea                       832
# CD Leganés                    832
# MKE Ankaragücü                829
# Júbilo Iwata                  827
# Empoli                        827
# Eintracht Frankfurt           825
# Bolton Wanderers              824
# Cerezo Osaka                  820
# Sagan Tosu                    818
# Vissel Kobe                   818
# Leicester City                818
# Manchester United             817
# Alanyaspor                    816
# Rayo Vallecano                816
# Hokkaido Consadole Sapporo    814
# West Ham United               814
# Name: Age, dtype: int64

# %%
# lets see the youngest team
df.groupby(['Club'])['Age'].sum().sort_values(ascending = True).head(20)
# Out:
# Club
# Derry City             398
# Sligo Rovers           421
# Limerick FC            436
# Tromsø IL              476
# FK Haugesund           508
# Bray Wanderers         511
# Shamrock Rovers        519
# Östersunds FK          525
# Wellington Phoenix     533
# Melbourne Victory      537
# Bohemian FC            537
# Dalkurd FF             540
# IFK Göteborg           542
# FC Nordsjælland        547
# LOSC Lille             550
# Odds BK                551
# FC Groningen           557
# Fiorentina             562
# GIF Sundsvall          563
# Forest Green Rovers    566
# Name: Age, dtype: int64

# %%
# The clubs and their players overalls
some_clubs = ('Juventus', 'Real Madrid', 'Manchester City', 'FC Barcelona', 'Paris FC', 'Manchester United')
df_club = df.loc[df['Club'].isin(some_clubs) & df['Age'] & df['Overall'] ]
plt.grid(True)

ax = sns.barplot(x=df_club['Club'], y=df_club['Overall'], palette="deep");
ax.set_title(label='Distribution overall in several clubs', fontsize=25);

# %%
# All of position
ax = sns.countplot(x = 'Position', data = df, palette = 'deep');
ax.set_title(label='Count of players on the position', fontsize=20);
plt.grid(True)
plt.show();

# %%
# Top 20 left-footed players
df[df['Preferred Foot'] == 'Left'][['Name','Overall']].head(20)
# Out:
#               Name  Overall
# 0         L. Messi       94
# 13     David Silva       90
# 15       P. Dybala       89
# 17    A. Griezmann       89
# 19     T. Courtois       89
# 24    G. Chiellini       89
# 26        M. Salah       88
# 28    J. Rodríguez       88
# 35         Marcelo       88
# 36         G. Bale       88
# 37       H. Lloris       88
# 42       S. Umtiti       87
# 47       R. Lukaku       87
# 49      Jordi Alba       87
# 51   J. Vertonghen       87
# 55         L. Sané       86
# 56  Bernardo Silva       86
# 57         Ederson       86
# 64     Alex Sandro       86
# 65   Douglas Costa       86

# %%
# Top 20 right-footed players
df[df['Preferred Foot'] == 'Right'][['Name','Overall']].head(20)
# Out:
#                  Name  Overall
# 1   Cristiano Ronaldo       94
# 2           Neymar Jr       92
# 3              De Gea       91
# 4        K. De Bruyne       91
# 5           E. Hazard       91
# 6           L. Modrić       91
# 7           L. Suárez       91
# 8        Sergio Ramos       91
# 9            J. Oblak       90
# 10     R. Lewandowski       90
# 11           T. Kroos       90
# 12           D. Godín       90
# 14           N. Kanté       89
# 16            H. Kane       89
# 18      M. ter Stegen       89
# 20    Sergio Busquets       89
# 21          E. Cavani       89
# 22           M. Neuer       89
# 23          S. Agüero       89
# 25          K. Mbappé       88

# %%
# Better is left-footed or rigth-footed players?
sns.lmplot(x = 'BallControl', y = 'Dribbling', data = df,
          scatter_kws = {'alpha':0.2},
          col = 'Preferred Foot');

# %%
# Crossing vs. dribbling
sns.jointplot(x=df['Dribbling'], y=df['Crossing'], kind="kde", color="#4CB391");

# %%
# Top 10 the most expensive clubs
df.groupby(['Club'])['Value'].sum().sort_values(ascending = False).head(10)
# Out:
# Club
# Frosinone               €9M€9M€6.5M€6M€7M€4.5M€3.2M€3.6M€875K€4.2M€1.5...
# Internacional           €9M€9.5M€9M€5M€6.5M€6M€1.7M€6M€5.5M€4.8M€2.1M€...
# Montreal Impact         €9M€8M€6.5M€750K€1.2M€2.7M€1.3M€1M€700K€600K€7...
# West Bromwich Albion    €9M€6M€8M€7.5M€6M€7M€6.5M€5.5M€1.3M€3.9M€7M€1....
# Changchun Yatai FC      €9M€6.5M€6M€2.1M€850K€825K€700K€725K€450K€375K...
# Dijon FCO               €9M€6.5M€6.5M€8.5M€3.8M€4.9M€6.5M€2.6M€4.6M€5....
# FC Schalke 04           €9M€20M€18.5M€18.5M€17.5M€12M€18M€12.5M€10.5M€...
# SV Zulte-Waregem        €9M€2.5M€2.4M€800K€1.4M€3.1M€2.1M€1.2M€825K€12...
# Beşiktaş JK             €9M€15.5M€13M€11.5M€17.5M€11.5M€11M€13M€10M€4M...
# River Plate             €9M€13.5M€12.5M€10M€2.1M€5M€6.5M€9.5M€4.1M€5.5...
# Name: Value, dtype: object

# %%
# Top 10 the most expensive clubs
df.groupby(['Club'])['Value'].sum().sort_values(ascending = True).head(10)
# Out:
# Club
# Júbilo Iwata          €0€2.2M€1M€375K€1.1M€850K€825K€200K€550K€290K€...
# ESTAC Troyes          €0€725K€1.8M€1.6M€1.4M€1.8M€1.1M€825K€1.6M€775...
# SpVgg Unterhaching    €1.1M€1.1M€850K€500K€600K€550K€375K€800K€525K€...
# Barnsley              €1.1M€1.2M€1.1M€1.2M€725K€1.2M€1.1M€950K€1.1M€...
# Motherwell            €1.1M€1.6M€675K€1M€600K€650K€825K€800K€700K€55...
# De Graafschap         €1.1M€1M€800K€750K€925K€750K€900K€950K€750K€60...
# Wycombe Wanderers     €1.1M€300K€950K€425K€230K€475K€850K€550K€575K€...
# FK Haugesund          €1.1M€375K€975K€475K€950K€675K€850K€575K€350K€...
# Hobro IK              €1.1M€600K€475K€475K€500K€875K€950K€425K€270K€...
# Vålerenga Fotball     €1.1M€675K€1.2M€700K€600K€850K€900K€700K€260K€...
# Name: Value, dtype: object

# %%
# Top 20 teams with the best players
df.groupby(['Club'])['Overall'].max().sort_values(ascending = False).head(20)
# Out:
# Club
# Juventus               94
# FC Barcelona           94
# Paris Saint-Germain    92
# Manchester City        91
# Chelsea                91
# Real Madrid            91
# Manchester United      91
# Atlético Madrid        90
# FC Bayern München      90
# Tottenham Hotspur      89
# Arsenal                88
# Liverpool              88
# Milan                  88
# Inter                  88
# Napoli                 88
# Lazio                  87
# Vissel Kobe            86
# Borussia Dortmund      86
# FC Schalke 04          85
# Valencia CF            85
# Name: Overall, dtype: int64

# %%
# bins = number of bar in figure
# color = color, label = label, linewidth = width of line, alpha = opacity, grid = grid, linestyle = sytle of line
data.SprintSpeed.plot(kind = 'hist',bins = 50,figsize = (20,20))
plt.grid(True)
plt.show()

# %%
data1 = data.loc[:,["Age","Potential","Overall"]]
data1.plot()

# %%
# subplot
data1.plot(subplots = True)
plt.show()
