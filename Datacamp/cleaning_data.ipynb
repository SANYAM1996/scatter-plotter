# %%
pwd
# Out:
# 'C:\\Users\\user\\OneDrive\\Desktop\\scatter-plotter\\Datacamp'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cd C:\\Users\\user\\OneDrive\\Desktop\\CSV files
# Out:
# C:\Users\user\OneDrive\Desktop\CSV files

# %%
df = pd.read_csv('literary_birth_rate.csv')
df
# Out:
#                  Country  Continent  female literacy  fertility  population
# 0                   Chine       ASI             90.5      1.769         1.0
# 1                    Inde       ASI             50.8      2.682         1.0
# 2                     USA       NAM             99.0      2.077       304.0
# 3               Indonésie       ASI             88.8      2.132       227.0
# 4                  Brésil       LAT             90.2      1.827       191.0
# ..                    ...       ...              ...        ...         ...
# 157               Vanuatu       OCE             79.5      3.883       233.0
# 158                 Samoa       OCE             98.5      3.852       178.0
# 159  Sao Tomé-et-Principe        AF             83.3      3.718       160.0
# 160                 Aruba       LAT             98.0      1.732       105.0
# 161                 Tonga       ASI             99.1      3.928       103.0
#
# [162 rows x 5 columns]

# %%
df.head()
# Out:
#     Country  Continent  female literacy  fertility  population
# 0      Chine       ASI             90.5      1.769         1.0
# 1       Inde       ASI             50.8      2.682         1.0
# 2        USA       NAM             99.0      2.077       304.0
# 3  Indonésie       ASI             88.8      2.132       227.0
# 4     Brésil       LAT             90.2      1.827       191.0

# %%
df['population'].value_counts()
# Out:
# 1.0     11
# 4.0     11
# 2.0      9
# 3.0      9
# 6.0      7
#         ..
# 30.0     1
# 33.0     1
# 34.0     1
# 39.0     1
# 24.0     1
# Name: population, Length: 74, dtype: int64

# %%
df['Continent'].value_counts()
# Out:
# AF     49
# ASI    45
# EUR    36
# LAT    24
# OCE     4
# NAM     2
# Name: Continent, dtype: int64

# %%
df['female literacy'].value_counts()
# Out:
# 99.0    15
# 99.7     4
# 99.8     3
# 95.9     3
# 91.5     3
#         ..
# 85.6     1
# 41.1     1
# 93.4     1
# 95.4     1
# 90.5     1
# Name: female literacy, Length: 115, dtype: int64

# %%
df['fertility'].value_counts()
# Out:
# 1.854    2
# 1.841    2
# 1.436    2
# 3.371    2
# 1.393    2
#         ..
# 4.967    1
# 2.508    1
# 1.281    1
# 4.859    1
# 2.000    1
# Name: fertility, Length: 155, dtype: int64

# %%
df.columns
# Out:
# Index(['Country ', 'Continent', 'female literacy', 'fertility', 'population'], dtype='object')

# %%
df.describe()
# Out:
#        female literacy   fertility  population
# count       160.000000  160.000000  160.000000
# mean         80.059375    2.897487   69.762500
# std          23.180534    1.425737  149.719255
# min          12.600000    1.212000    1.000000
# 25%          66.250000    1.833750    4.750000
# 50%          90.000000    2.388500   12.500000
# 75%          98.500000    3.883500   46.500000
# max         100.000000    7.069000  862.000000

# %%
df.fertility.plot('hist')
# Out:
# c:\python\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='hist')` instead of `Series.plot('hist',)`.
#   """Entry point for launching an IPython kernel.

# %%
a = df[df.population > 100]
a
# Out:
#                  Country  Continent  female literacy  fertility  population
# 2                     USA       NAM             99.0      2.077       304.0
# 3               Indonésie       ASI             88.8      2.132       227.0
# 4                  Brésil       LAT             90.2      1.827       191.0
# 5                Pakistan       ASI             40.0      3.872       166.0
# 6              Bangladesh       ASI             49.8      2.288       160.0
# 7                 Nigéria        AF             48.8      5.173       151.0
# 8    Fédération de Russie       EUR             99.4      1.393       141.0
# 9                   Japan       ASI             99.0      1.262       127.0
# 10                Mexique       LAT             91.5      2.156       106.0
# 144                Chypre       EUR             96.7      1.516       862.0
# 145               Bahreïn       ASI             89.4      2.233       775.0
# ...

# %%
df[df.fertility > 5]
# Out:
#                         Country  Continent  female literacy  fertility  \
# 7                        Nigéria        AF             48.8      5.173
# 15                      Ethiopie        AF             22.8      5.211
# 19    Rép. Démocratique du Congo        AF             56.1      5.908
# 29   République-Unie de Tanzanie        AF             66.3      5.520
# 36                       Ouganda        AF             66.8      6.254
# 39                   Afghanistan       ASI             12.6      6.505
# 48                         Yémen       ASI             42.8      5.100
# 56                        Angola        AF             57.0      5.637
# 60                  Burkina Faso        AF             21.6      5.841
# 61                        Malawi        AF             65.8      5.455
# 62                         Niger        AF             15.1      7.069
# 66                          Mali        AF             18.2      5.405
# ...

# %%
sns.boxplot('fertility',data = df,hue = 'population')

# %%
sns.relplot(x = 'fertility',y = 'female literacy',data = df ,hue = 'Continent')

# %%
sns.countplot(x = 'Continent',data = df)

# %%
a.population.plot('hist')
# Out:
# c:\python\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='hist')` instead of `Series.plot('hist',)`.
#   """Entry point for launching an IPython kernel.

# %%
b = df[(df['Continent']=='EUR') & (df['female literacy']>50) & (df['population']>150)]

# %%
b
# Out:
#     Country  Continent  female literacy  fertility  population
# 144   Chypre       EUR             96.7      1.516       862.0
# 152    Malte       EUR             93.5      1.251       411.0
# 155  Iceland       EUR             99.0      2.093       317.0

# %%
sns.catplot(x ='female literacy',y = 'population' ,hue = 'Continent',data = b)

# %%
c = (df['female literacy']>50) | (df['population']>150)

# %%
c
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 157    True
# 158    True
# 159    True
# 160    True
# 161    True
# Length: 162, dtype: bool

# %%
sns.boxplot(x = 'Continent', y='population', data = df,color = 'g')
plt.title('continent vs population')
plt.grid(True)
